# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import requests


service = Service(ChromeDriverManager().install())
nav = webdriver.Chrome(service=service)

class AutomatizarDados:
    def __init__(self):
        ...

    def entrando_no_site_e_furto_veiculo(self):
        self.nav.get(self.link)
        self.nav.find_element('xpath', '//*[@id="cphBody_btnFurtoVeiculo"]').click()
    
    def apertando_botao_exportar(self):
        self.nav.find_element('xpath', '//*[@id="cphBody_ExportarBOLink"]').click()

    def escolhendo_o_mes(self)
        self.














# print('Seja bem vindo! Escolha sua próxima ação: ')
# print('''
#     [0] Sair da aplicação
#     [1] Dados dos últimos 3 anos (2020, 2021 e 2022)
#     [2] Exportar todos os dados (anos e meses)
#     [3] Escolha o ano, mês inicial e final que você deseja esportar
#     ''')

# while True:
#     acao_do_usuario = int(input('Digite sua ação: '))

#     if acao_do_usuario == 0:
#         break
#     elif acao_do_usuario == 1:
#         nav.get('https://www.ssp.sp.gov.br/transparenciassp/Consulta2022.aspx')
#         nav.find_element('xpath', '//*[@id="cphBody_btnFurtoVeiculo"]').click()
#         nav.find_element('xpath', f'//*[@id="cphBody_lkAno21"]').click()
#         nav.find_element('xpath', f'//*[@id="cphBody_listMes2"]').click()
#         nav.find_element('xpath', '//*[@id="cphBody_ExportarBOLink"]').click()
#         nav.find_element('xpath', f'//*[@id="cphBody_lkAno22"]').click()
#         nav.find_element('xpath', f'//*[@id="cphBody_listMes3"]').click()
#         nav.find_element('xpath', '//*[@id="cphBody_ExportarBOLink"]').click()
#     elif acao_do_usuario == 2:
#         print('Exportando todas as informações')
#     elif acao_do_usuario == 3:
#         print('Exportando todos os dados pedidos ')
#     else:
#         print('Valor invalido')
# print('Fim da Aplicação')


            


# user_month = int(input('Digite o mês: '))
# user_year = int(input('Digite o ano: '))

# nav.get('https://www.ssp.sp.gov.br/transparenciassp/Consulta2022.aspx')
# nav.find_element('xpath', '//*[@id="cphBody_btnFurtoVeiculo"]').click()
# nav.find_element('xpath', f'//*[@id="cphBody_lkAno{user_year}"]').click()
# nav.find_element('xpath', f'//*[@id="cphBody_listMes{user_month}"]').click()
# nav.find_element('xpath', '//*[@id="cphBody_ExportarBOLink"]').click()
# Out:
#   Cell In[3], line 13
#     def entrando_no_site_e_furto_veiculo(self):
#     ^
# IndentationError: expected an indented block after function definition on line 10
